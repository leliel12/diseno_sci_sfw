# %% [markdown]
# # Devoluciónn GriSPy
#
# - **Repository:** https://github.com/mchalela/GriSPy
# - **Fecha:** 2019/10/26

# %% [markdown]
# ## Requerimientos
#
#
# ### Eliminar `clean()` de `test_io.py`
#
# OK
#
# ### Bueno los fixtures lo usan como `@fixture` o como `setup_method`. Lean la documentación para ver la diferencia. `SetUp` es del framework unittest no de pytest.
#
# ok
#
# ### Agreguen una info sobre la licencia a todos sus archivos *.py*.
#
# Falta en: tests/__init__.py
#
# ### Instalen *pydocstyle* en un environment de tox y ejecuten el comando: `pydocstyle grispy` en ese environment. Llamen a ese evironment tox **docstyle**. Eso lo que va a hacer es informarle sobre documentación faltante. No hay muchos errores.
#
# OK
#
#
# ### Fijense de ordenar todos los imports como dice pep-8
#
# - Primero builtins
# - Bibliotecas de terceros agrupadas
# - Mis bilbliotecas de proyecto
#
# En el caso `test_io.py` quedaria algo asi
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import datetime as dt
dt.datetime.now()
# Out:
# datetime.datetime(2019, 10, 26, 17, 14, 6, 373604)
