# %% [markdown]
# # Devolución Piscis
#
# - **Repository:** https://github.com/mkoraj/piscis
# - **Fecha:** 2019/10/27

# %% [markdown]
# ## Requerimientos
#
# - Los tests no andan.
# - La licencia en `LICENSE` dice ser *MIT* pero las cabeceras dicen BSD-3.
# - Las views andan pero me manda directamente al django admin.
# - Estaria bueno que empiezen a integrar tests, y estilo de una manera mas robusta. El código es extrañp y no sigue una convencion.
#
#     - Un caso que me llamo la atención fue que una view responde un texto plano que no lleva a ningun lado.
#     - Vayan armando de entrada una jerarquia de templates que funcionen bien.
#     - Hay prints que salen en la consola con los querysets

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import datetime as dt
dt.datetime.now()
# Out:
# datetime.datetime(2019, 10, 27, 2, 0, 57, 939749)
