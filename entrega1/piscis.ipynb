# %% [markdown]
# # Devolución Piscis
#
# - **Repository:** https://github.com/mkoraj/piscis
# - **Fecha:** 2019/10/02

# %% [markdown]
# ## Requerimientos
#
# ### LICENSE, README completo.
#
# - [LICENSE](https://github.com/mkoraj/piscis/blob/master/LICENSE): MIT.
#     - Fijense el copyright solo dice *mkoraj*. Ponga como corresponde.
#     - Pueden poner varios autores separados por comas.
#
#
# - El [README.md](https://github.com/mkoraj/piscis/blob/master/README.md) no establece cuál es la versión de python a correr.
#
# - [requirements.txt](https://github.com/mkoraj/piscis/blob/master/requirements.txt)
#     - Al parecer estoy necesitando anaconda. Si es asi hay que aclararlo en el README. De todas formas un requirements para anaconda y uno para pip seria de agradecer.
#     - Por lo que veo aca (puedo equivocarme) se puede usar el mismo requirements.txt de pip para crear un entorno anaconda. https://stackoverflow.com/questions/51042589/conda-version-pip-install-r-requirements-txt-target-lib/51043636.
#     - Probando creo que solo dependen de django y pilow
#
# ### Modelos completos.
#
# - Me parece que estan olvidando que van a necesitar guardar muchos mas datos sobre usuarios, que los que por defecto trae django.
# - Documenten un poco los modelos.
#
# ### Tests de todos los modelos.
#
# No logre hacer andar los tests. Como no hay ni una info de como correrlos probe
#
# ```bash
# $ python manage.py test piscis
# System check identified no issues (0 silenced).
#
# ----------------------------------------------------------------------
# Ran 0 tests in 0.000s
#
# OK
#
# $ python manage.py test app
# System check identified no issues (0 silenced).
#
# ----------------------------------------------------------------------
# Ran 0 tests in 0.000s
#
# OK
# ```
#
# En ambos casos no hubo test corriendo.
#
# Abriendo el test no encontre NADA solo un mock vacio sin ningun clase que herede de `TestCase`
# https://github.com/mkoraj/piscis/blob/master/app/tests.py
#
#
# ## Notas
#
# - Solo hay tres personas trabajando.
# - El ùltimo comit no agrega casi nada.(https://github.com/mkoraj/piscis/commit/892d1994fd5430861e4b7a42a9720482f8ad4bde)
# - Donde estan los miembros faltantes del grupo?

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import datetime as dt
dt.datetime.now()
# Out:
# datetime.datetime(2019, 10, 2, 11, 35, 50, 404856)
