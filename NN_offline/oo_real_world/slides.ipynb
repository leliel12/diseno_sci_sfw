# %% [markdown]
# # Diseño de software
# ----
#
# ## Clases en el mundo real
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### namedtuples

# %%
from collections import namedtuple

Coso = namedtuple("Coso", ["a", "b"])

c  = Coso(a=1, b=2)
c
# Out:
# Coso(a=1, b=2)

# %% [markdown]
# ### dataclass

# %%
import dataclasses

@dataclasses.dataclass
class InventoryItem:
    '''Class for keeping track of an item in inventory.'''
    name: str
    unit_price: float
    quantity_on_hand: int = 0

# %%
InventoryItem(name="tito", unit_price=43)
# Out:
# InventoryItem(name='tito', unit_price=43, quantity_on_hand=0)

# %%
InventoryItem(name=23, unit_price=43)
# Out:
# InventoryItem(name=23, unit_price=43, quantity_on_hand=0)

# %% [markdown]
# ### dataclass

# %%
import dataclasses

@dataclasses.dataclass
class InventoryItem:
    '''Class for keeping track of an item in inventory.'''
    name: str
    unit_price: float
    quantity_on_hand: int = 0
    discount_20p: float = dataclasses.field(init=False)
        
    def __post_init__(self):
        self.discount_20p = self.unit_price * 0.2
    
InventoryItem(name=23, unit_price=43)
# Out:
# InventoryItem(name=23, unit_price=43, quantity_on_hand=0, discount_20p=8.6)

# %% [markdown]
# ## Classes en el mundo real
# ----
#
# ### attrs

# %%
# !pip install attrs -U
# Out:
# Requirement already satisfied: attrs in /home/juanbc/proyectos/dis_ssw/lib/python3.10/site-packages (23.1.0)
#
# [notice] A new release of pip available: 22.3 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import attrs

@attrs.define
class SomeClass:
    a_number = attrs.field(default=42)
    list_of_numbers: list = attrs.field(factory=list)
    
    @a_number.validator
    def must_be_a_number(self, attribute, value):
        if not isinstance(value, (int, float)):
            raise TypeError()
            
    def hard_math(self, another_number):
        return self.a_number + sum(self.list_of_numbers) * another_number

sc = SomeClass(1, {1, 2, 3})
sc
# Out:
# SomeClass(a_number=1, list_of_numbers={1, 2, 3})

# %%
sc.hard_math(23)
# Out:
# 139

# %% [markdown]
# ### attrs - Privados

# %%
@attrs.define
class C(object):
    _x = attrs.field(repr=False)
    y = attrs.field()
    

C(x=1, y=2)
# Out:
# C(y=2)

# %% [markdown]
# ### attrs -  Privados auto-inicializados

# %%
@attrs.define
class C(object):
    _x = attrs.field(init=False, default=42)
    y = attrs.field()
C(34)
# Out:
# C(_x=42, y=34)

# %% [markdown]
# ### attrs -  Keyword only

# %%
@attrs.define
class A:
    a = attrs.field()

A(a=1)
A(1)
# Out:
# A(a=1)

# %% [markdown]
# ### attrs - Utilidades

# %%
@attrs.define
class Coordinates:
    x = attrs.field()
    y = attrs.field()

attrs.asdict(Coordinates(x=1, y=2))
{'x': 1, 'y': 2}
# Out:
# {'x': 1, 'y': 2}

# %%
@attrs.define
class C1:
    x = attrs.field()
    y = attrs.field()
    
C2 = attrs.make_class("C2", ["x", "y"])

attrs.fields(C1) == attrs.fields(C2)
# Out:
# True

# %% [markdown]
# ### attrs - Inmutabilidad

# %%
@attrs.define(frozen=True)
class C:
    x = attrs.field()

i = C(1)
i.x = 2
# Out:
# ---------------------------------------------------------------------------
# FrozenInstanceError                       Traceback (most recent call last)
# Input In [14], in <cell line: 6>()
#       3     x = attrs.field()
#       5 i = C(1)
# ----> 6 i.x = 2
#
# File ~/proyectos/dis_ssw/lib/python3.10/site-packages/attr/_make.py:605, in _frozen_setattrs(self, name, value)
#     602     BaseException.__setattr__(self, name, value)
#     603     return
# --> 605 raise FrozenInstanceError()
#
# FrozenInstanceError:

# %% [markdown]
# ### attrs - Inicializacion por defecto basada en otros parámetros

# %%
@attrs.define
class ConCoordinates:
    
    x = attrs.field()
    y = attrs.field()
    coordinates = attrs.field(init=False)

    @coordinates.default
    def _coordinates_default(self):
        return Coordinates(x=self.x, y=self.y)

# %%
ConCoordinates(x=23, y=21)
# Out:
# ConCoordinates(x=23, y=21, coordinates=Coordinates(x=23, y=21))

# %% [markdown]
# ## attrs - Converters

# %%
@attrs.define
class C:
    x: int = attrs.field(converter=int)
        
C(1.1)
# Out:
# C(x=1)

# %% [markdown]
# ## attrs - Validators

# %%
@attrs.define
class C:
    x: int = attrs.field(converter=int)
        
    @x.validator
    def _x_validator(self, name, value):
        assert self.x > 1
        
C(2)
# Out:
# C(x=2)

# %% [markdown]
# ## attrs - Validators
#
# Como funciones

# %%
def gt_1(instance, field, value):
    if value <= 1:
        raise ValueError(f"{field.name!r} must be gt 1")

@attrs.define
class C:
    x: int = attrs.field(converter=int, validator=gt_1)
    y: int = attrs.field(converter=int, validator=gt_1)
     
        
C(2, 1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [19], in <cell line: 11>()
#       7     x: int = attrs.field(converter=int, validator=gt_1)
#       8     y: int = attrs.field(converter=int, validator=gt_1)
# ---> 11 C(2, 1)
#
# File <attrs generated init __main__.C-5>:7, in __init__(self, x, y)
#       5 if _config._run_validators is True:
#       6     __attr_validator_x(self, __attr_x, self.x)
# ----> 7     __attr_validator_y(self, __attr_y, self.y)
#
# Input In [19], in gt_1(instance, field, value)
#       1 def gt_1(instance, field, value):
#       2     if value <= 1:
# ----> 3         raise ValueError(f"{field.name!r} must be gt 1")
#
# ValueError: 'y' must be gt 1

# %% [markdown]
# ## attrs - Inicializacion libre - `post-init`

# %%
@attrs.define
class C:
    x: int
    y: int = attrs.field(init=False)

    def __attrs_post_init__(self):
        self.y = self.x + 1

C(1)
# Out:
# C(x=1, y=2)

# %% [markdown]
# ## attrs - Inicializacion libre - `post-init`
#
# Si es `frozen`Ojo!

# %%
@attrs.define(frozen=True)
class C:
    x: int
    y: int = attrs.field(init=False)

    def __attrs_post_init__(self):
        self.y = self.x + 1

C(1)
# Out:
# ---------------------------------------------------------------------------
# FrozenInstanceError                       Traceback (most recent call last)
# Input In [21], in <cell line: 9>()
#       6     def __attrs_post_init__(self):
#       7         self.y = self.x + 1
# ----> 9 C(1)
#
# File <attrs generated init __main__.C-7>:4, in __init__(self, x)
#       2 _setattr = _cached_setattr_get(self)
#       3 _setattr('x', x)
# ----> 4 self.__attrs_post_init__()
#
# Input In [21], in C.__attrs_post_init__(self)
#       6 def __attrs_post_init__(self):
# ----> 7     self.y = self.x + 1
#
# File ~/proyectos/dis_ssw/lib/python3.10/site-packages/attr/_make.py:605, in _frozen_setattrs(self, name, value)
#     602     BaseException.__setattr__(self, name, value)
#     603     return
# --> 605 raise FrozenInstanceError()
#
# FrozenInstanceError:

# %% [markdown]
# ## attrs - Inicializacion libre - `post-init`
#
# Si es `frozen`Ojo! - **solución**

# %%
@attrs.define(frozen=True)
class C:
    x: int
    y: int = attrs.field(init=False)

    def __attrs_post_init__(self):
        super().__setattr__("y", self.x + 1)
        

C(1)
# Out:
# C(x=1, y=2)

# %% [markdown]
# ## attrs - Inicializacion libre - `pre-init`
#
# The sole reason for the existence of __attrs_pre_init__ is to give users the chance to call super().__init__(), because some subclassing-based APIs require that.

# %%
class Base:
    def __init__(self):
        print("iniciando")


@attrs.define
class C(Base):
    x: int
    def __attrs_pre_init__(self):
        super().__init__()
        
C(1)
# Out:
# iniciando
# C(x=1)

# %% [markdown]
# # Uttrs: Units + Attrs
#
# ![image.png](attachment:image.png)

# %%
# !pip install uttrs
# Out:
# Requirement already satisfied: uttrs in /home/juanbc/proyectos/dis_ssw/lib/python3.10/site-packages (0.5)
# Requirement already satisfied: attrs in /home/juanbc/proyectos/dis_ssw/lib/python3.10/site-packages (from uttrs) (23.1.0)
# Requirement already satisfied: astropy in /home/juanbc/proyectos/dis_ssw/lib/python3.10/site-packages (from uttrs) (5.1)
# Requirement already satisfied: pyerfa>=2.0 in /home/juanbc/proyectos/dis_ssw/lib/python3.10/site-packages (from astropy->uttrs) (2.0.0.1)
# Requirement already satisfied: numpy>=1.18 in /home/juanbc/proyectos/dis_ssw/lib/python3.10/site-packages (from astropy->uttrs) (1.23.1)
# Requirement already satisfied: PyYAML>=3.13 in /home/juanbc/proyectos/dis_ssw/lib/python3.10/site-packages (from astropy->uttrs) (6.0)
# Requirement already satisfied: packaging>=19.0 in /home/juanbc/proyectos/dis_ssw/lib/python3.10/site-packages (from astropy->uttrs) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/juanbc/proyectos/dis_ssw/lib/python3.10/site-packages (from packaging>=19.0->astropy->uttrs) (3.0.9)
#
# [notice] A new release of pip available: 22.3 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Uttrs: Ejemplo

# %%
from astropy import units as u
import uttr
import attrs

@uttr.s
class Galaxy:
    x = uttr.ib(unit=u.kpc)
    y = uttr.ib(unit=u.kpc)
    z = uttr.ib(unit=u.kpc)

    vx = uttr.ib(unit=u.km / u.s)
    vy = uttr.ib(unit=u.km / u.s)
    vz = uttr.ib(unit=u.km / u.s)

    m = uttr.ib(unit=u.M_sun)

    notes = attrs.field(validator=attrs.validators.instance_of(str))
    
gal = Galaxy(
    x=[1, 1, 3, 4],
    y=[10, 2, 3, 100],
    z=[1000, 1000, 1000, 1000] * u.parsec,
    vx=[1000, 1023, 2346, 1334],
    vy=[9956, 833, 954, 1024] * (u.km / u.h),
    vz=[1253, 956, 1054, 3568],
    m=[200, 100, 20, 5] * u.kg,
    notes="A random galaxy with arbitrary numbers.",
)
gal
# Out:
# Galaxy(x=<Quantity [1., 1., 3., 4.] kpc>, y=<Quantity [ 10.,   2.,   3., 100.] kpc>, z=<Quantity [1000., 1000., 1000., 1000.] pc>, vx=<Quantity [1000., 1023., 2346., 1334.] km / s>, vy=<Quantity [9956.,  833.,  954., 1024.] km / h>, vz=<Quantity [1253.,  956., 1054., 3568.] km / s>, m=<Quantity [200., 100.,  20.,   5.] kg>, notes='A random galaxy with arbitrary numbers.')

# %% [markdown]
# # Uttrs: Units + Attrs
#
# Cada atributo tiene acceso a todas las funcionalidades de units

# %%
gal.x
# Out:
# <Quantity [1., 1., 3., 4.] kpc>

# %%
gal.vy.to(u.m / u.ms)
# Out:
# <Quantity [2.76555556, 0.23138889, 0.265     , 0.28444444] m / ms>

# %%
gal.vx.to_value()
# Out:
# array([1000., 1023., 2346., 1334.])

# %% [markdown]
# # Uttrs: Units + Attrs
#
# Las unidades son lentas.
# Se agrega un atributo de clase extra llamado "arr_" que permite acceder a todas las `uttr.ib` como numpy array

# %%
gal.arr_.x, gal.x.to_value()  # equivalente
# Out:
# (array([1., 1., 3., 4.]), array([1., 1., 3., 4.]))

# %% [markdown]
# # Uttrs: Units + Attrs
#
# Las unidades son lentas.
# Se agrega un atributo de clase extra llamado "arr_" que permite acceder a todas las `uttr.ib` como numpy array

# %%
import numpy as np

@uttr.s
class Galaxy:
    x = uttr.ib(unit=u.kpc)
    y = uttr.ib(unit=u.kpc)
    z = uttr.ib(unit=u.kpc)

    vx = uttr.ib(unit=u.km / u.s)
    vy = uttr.ib(unit=u.km / u.s)
    vz = uttr.ib(unit=u.km / u.s)

    m = uttr.ib(unit=u.M_sun)

    notes = attrs.field(validator=attrs.validators.instance_of(str))
    
    def mean(self):
        x = np.mean(self.arr_.x)
        y = np.mean(self.arr_.y)
        z = np.mean(self.arr_.z)

        vx = np.mean(self.arr_.vx)
        vy = np.mean(self.arr_.vy)
        vz = np.mean(self.arr_.vz)

        m = np.mean(self.arr_.m)

        return Galaxy(
            x=x, y=y, z=z, vx=vx, vy=vy, vz=vz, m=m, notes=self.notes
        )

# %% [markdown]
# # Uttrs: Units + Attrs
#
# Las unidades son lentas.
# Se agrega un atributo de clase extra llamado "arr_" que permite acceder a todas las `uttr.ib` como numpy array

# %%
gal = Galaxy(
    x=[1, 1, 3, 4],
    y=[10, 2, 3, 100],
    z=[1000, 1000, 1000, 1000] * u.parsec,
    vx=[1000, 1023, 2346, 1334],
    vy=[9956, 833, 954, 1024] * (u.km / u.h),
    vz=[1253, 956, 1054, 3568],
    m=[200, 100, 20, 5] * u.kg,
    notes="A random galaxy with arbitrary numbers.",
)

gal.mean()
# Out:
# Galaxy(x=<Quantity 2.25 kpc>, y=<Quantity 28.75 kpc>, z=<Quantity 1. kpc>, vx=<Quantity 1425.75 km / s>, vy=<Quantity 0.88659722 km / s>, vz=<Quantity 1707.75 km / s>, m=<Quantity 4.08617968e-29 solMass>, notes='A random galaxy with arbitrary numbers.')
